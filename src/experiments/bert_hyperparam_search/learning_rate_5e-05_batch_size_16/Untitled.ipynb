# %%
import pandas as pd

fp = pd.read_csv('false_pos_val.txt', sep=',', header=None, names=['word', 'score'])
fp = fp.sort_values(by='score', axis=0, ascending=False)
fp
# Out:
#                            word  score
# 1150                     medial  0.996
# 961                         igg  0.995
# 1998                  virulence  0.995
# 429                  contagious  0.994
# 1867                     tendon  0.994
# 960                         ige  0.994
# 310                    cerebrum  0.993
# 1882                      thigh  0.993
# 1573                     rabies  0.993
# 824                   glycolsis  0.992
# 146                    asteroid  0.991
# 150                         atm  0.991
# 1874                tetrahedral  0.990
# 962                         igm  0.990
# 1747                    somites  0.990
# 643                  epididymis  0.990
# 2022               white matter  0.989
# 1591              recessiveness  0.989
# 125                     archaea  0.989
# 739                   forebrain  0.989
# 1553      pulmonary ventilation  0.988
# 958                         iga  0.988
# 1001                  insertion  0.987
# ...
